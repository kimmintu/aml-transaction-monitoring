# %% [markdown]
# # Directed GraphSage Model using StellarGraph Library
#
# Inductive Representation Learning on Large Graphs. W.L. Hamilton, R. Ying, and J. Leskovec arXiv:1706.02216 [cs.SI], 2017.
#
# Based on the open source: https://stellargraph.readthedocs.io/en/stable/demos/node-classification/directed-graphsage-node-classification.html

# %% [markdown]
# This example shows the application of *directed* GraphSAGE to a *directed* graph, where the in-node and out-node neighbourhoods are separately sampled and have different weights.

# %% [markdown]
# Import stellargraph:

# %%
# install StellarGraph if running on Google Colab
import sys
if 'google.colab' in sys.modules:
  # %pip install -q stellargraph[demos]==1.2.1

# %%
# verify that we're using the correct version of StellarGraph for this notebook
import stellargraph as sg

try:
    sg.utils.validate_notebook_version("1.2.1")
except AttributeError:
    raise ValueError(
        f"This notebook requires StellarGraph version 1.2.1, but a different version {sg.__version__} is installed.  Please see <https://github.com/stellargraph/stellargraph/issues/1172>."
    ) from None

# %%
import pandas as pd
import os

import stellargraph as sg
from stellargraph.mapper import DirectedGraphSAGENodeGenerator
from stellargraph.layer import DirectedGraphSAGE

from tensorflow.keras import layers, optimizers, losses, metrics, Model
from sklearn import preprocessing, feature_extraction
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import sklearn
from stellargraph import datasets
from IPython.display import display, HTML
import matplotlib.pyplot as plt
# %matplotlib inline

from stellargraph import StellarGraph
import json
from networkx.readwrite import json_graph
import networkx as nx
import numpy as np
from collections import Counter
import tempfile
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from utils import *

# %%
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# ### Read the AML simulated transaction data

# %%
data_path = './data_small_graph/'
combined_directed_G = load_networkx_graphs(data_path)
# Out:
# 1000_Network_p_0.002_w_0.003.json  - max_node_id= -1
# 1000_Network_p_0.002_w_0.008.json  - max_node_id= 999
# 1000_Network_p_0.002_w_0.009.json  - max_node_id= 1999
# 1000_Network_p_0.004_w_0.004.json  - max_node_id= 2999
# 1000_Network_p_0.004_w_0.007.json  - max_node_id= 3999
# 1000_Network_p_0.004_w_0.009.json  - max_node_id= 4999
# 1000_Network_p_0.005_w_0.009.json  - max_node_id= 5999
# 1000_Network_p_0.006_w_0.007.json  - max_node_id= 6999
# 1000_Network_p_0.007_w_0.002.json  - max_node_id= 7999
# 1000_Network_p_0.007_w_0.009.json  - max_node_id= 8999
# 1000_Network_p_0.007_w_0.010.json  - max_node_id= 9999
# 1000_Network_p_0.008_w_0.000.json  - max_node_id= 10999
# 1000_Network_p_0.008_w_0.005.json  - max_node_id= 11999
# 1000_Network_p_0.008_w_0.007.json  - max_node_id= 12999
# 1000_Network_p_0.010_w_0.001.json  - max_node_id= 13999
# 1000_Network_p_0.010_w_0.006.json  - max_node_id= 14999
# 1000_Network_p_0.011_w_0.003.json  - max_node_id= 15999
# 1000_Network_p_0.011_w_0.005.json  - max_node_id= 16999
# 1000_Network_p_0.011_w_0.006.json  - max_node_id= 17999
# 1000_Network_p_0.012_w_0.002.json  - max_node_id= 18999
# 1000_Network_p_0.013_w_0.006.json  - max_node_id= 19999
# 1000_Network_p_0.014_w_0.003.json  - max_node_id= 20999
# 1000_Network_p_0.014_w_0.008.json  - max_node_id= 21999
# 1000_Network_p_0.015_w_0.006.json  - max_node_id= 22999
# 1000_Network_p_0.015_w_0.008.json  - max_node_id= 23999
# 1000_Network_p_0.016_w_0.003.json  - max_node_id= 24999
# 1000_Network_p_0.016_w_0.004.json  - max_node_id= 25999
# 1000_Network_p_0.016_w_0.005.json  - max_node_id= 26999
# 1000_Network_p_0.019_w_0.004.json  - max_node_id= 27999
# 1000_Network_p_0.019_w_0.007.json  - max_node_id= 28999
# 1000_Network_p_0.020_w_0.007.json  - max_node_id= 29999
# 1000_Network_p_0.021_w_0.004.json  - max_node_id= 30999
# 1000_Network_p_0.021_w_0.006.json  - max_node_id= 31999
# 1000_Network_p_0.021_w_0.007.json  - max_node_id= 32999
# 1000_Network_p_0.023_w_0.002.json  - max_node_id= 33999
# 1000_Network_p_0.024_w_0.001.json  - max_node_id= 34999
# 1000_Network_p_0.024_w_0.006.json  - max_node_id= 35999
# 1000_Network_p_0.027_w_0.000.json  - max_node_id= 36999
# 1000_Network_p_0.029_w_0.000.json  - max_node_id= 37999
# 1000_Network_p_0.031_w_0.003.json  - max_node_id= 38999
# 1000_Network_p_0.033_w_0.004.json  - max_node_id= 39999
# 1000_Network_p_0.035_w_0.001.json  - max_node_id= 40999
# 1000_Network_p_0.040_w_0.002.json  - max_node_id= 41999
# 1000_Network_p_0.047_w_0.001.json  - max_node_id= 42999

# %%
def generate_stellar_graph(combined_directed_G):
    node_feature_df, node_type_labels, _ = retrieve_node_features_and_labels_tuple(combined_directed_G)
    graph_feature = {i: [edge[2]['weight'] for edge in list(combined_directed_G.out_edges(i, data=True))] for i in list(combined_directed_G.nodes)}
    # max_features = max([len(node_feature) for node_feature in graph_feature.values()])    
    max_features = 150 # use fix feature numbers to runable and consistant on every graphs
    for key, value in graph_feature.items():
        if len(value) > max_features:
            graph_feature[key] = value[0: max_features]
        else:
            graph_feature[key].extend([0] * (max_features - len(value)))
    
    networkx_G = nx.DiGraph()
    networkx_G.add_edges_from(combined_directed_G.edges(data=True))
    nx.set_node_attributes(
        networkx_G,
        graph_feature,
        "feature",
    )

    G = StellarGraph.from_networkx(networkx_G, node_features="feature",
                                   node_type_default="account", edge_type_default="transaction")
    return G, node_type_labels, node_feature_df

# %%
G, node_subjects, node_features = generate_stellar_graph(combined_directed_G)

# %%
X = node_features
Y = node_subjects

# %%
print(G.info())
# Out:
# StellarDiGraph: Directed multigraph
#  Nodes: 44000, Edges: 1384756
#
#  Node types:
#   account: [44000]
#     Features: float32 vector, length 150
#     Edge types: account-transaction->account
#
#  Edge types:
#     account-transaction->account: [1384756]
#         Weights: range=[1.97201e-07, 1], mean=0.506063, std=0.291919
#         Features: none

# %% [markdown]
# ### Splitting the data

# %% [markdown]
# For machine learning we want to take a subset of the nodes for training, and use the rest for testing. We'll use scikit-learn again to do this

# %%
train_subjects, val_subjects = train_test_split(node_subjects, test_size=0.2)
train_subjects, test_subjects = train_test_split(train_subjects, test_size=0.2)

# %% [markdown]
# Note using stratified sampling gives the following counts:

# %%
neg, pos = np.bincount(train_subjects)
total = neg + pos
print('Examples:\n    Train: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Train: 28160
#     Positive: 3974 (14.11% of total)

# %%
neg, pos = np.bincount(val_subjects)
total = neg + pos
print('Examples:\n    Valuation: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Valuation: 8800
#     Positive: 1219 (13.85% of total)

# %%
neg, pos = np.bincount(test_subjects)
total = neg + pos
print('Examples:\n    Test: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Test: 7040
#     Positive: 1021 (14.50% of total)

# %%
neg, pos = np.bincount(node_subjects)
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 44000
#     Positive: 6214 (14.12% of total)

# %% [markdown]
# The training set has class imbalance that might need to be compensated, e.g., via using a weighted cross-entropy loss in model training, with class weights inversely proportional to class support. However, we will ignore the class imbalance in this example, for simplicity.

# %% [markdown]
# ### Converting to numeric arrays

# %% [markdown]
# For our categorical target, we will use one-hot vectors that will be fed into a soft-max Keras layer during training. To do this conversion ...

# %%
target_encoding = preprocessing.LabelBinarizer()
train_targets = target_encoding.fit_transform(train_subjects)
val_targets = target_encoding.transform(val_subjects)
test_targets = target_encoding.transform(test_subjects)

# %% [markdown]
# We now do the same for the node attributes we want to use to predict the subject. These are the feature vectors that the Keras model will use as input. The CORA dataset contains attributes 'w_x' that correspond to words found in that publication. If a word occurs more than once in a publication the relevant attribute will be set to one, otherwise it will be zero.

# %% [markdown]
# ## Creating the GraphSAGE model in Keras

# %% [markdown]
# To feed data from the graph to the Keras model we need a data generator that feeds data from the graph to the model. The generators are specialized to the model and the learning task so we choose the `DirectedGraphSAGENodeGenerator` as we are predicting node attributes with a `DirectedGraphSAGE` model.
#
# We need two other parameters, the `batch_size` to use for training and the number of nodes to sample at each level of the model. Here we choose a two-level model with 10 nodes sampled in the first layer (5 in-nodes and 5 out-nodes), and 4 in the second layer (2 in-nodes and 2 out-nodes).

# %%
batch_size = 50 # default = 50
in_samples = [5, 2] # 5 in-directed edges in 1st layer, 2 in 2nd layer
out_samples = [5, 2] # 5 out-directed edge in 1st layer, 2 in 2nd layer

# %% [markdown]
# A `DirectedGraphSAGENodeGenerator` object is required to send the node features in sampled subgraphs to Keras

# %%
generator = DirectedGraphSAGENodeGenerator(G, batch_size, in_samples, out_samples)

# %% [markdown]
# Using the `generator.flow()` method, we can create iterators over nodes that should be used to train, validate, or evaluate the model. For training we use only the training nodes returned from our splitter and the target values. The `shuffle=True` argument is given to the `flow` method to improve training.

# %%
train_gen = generator.flow(train_subjects.index, train_targets, shuffle=True)

# %% [markdown]
# Now we can specify our machine learning model, we need a few more parameters for this:
#
#  * the `layer_sizes` is a list of hidden feature sizes of each layer in the model. In this example we use 32-dimensional hidden node features at each layer, which corresponds to 12 weights for each head node, 10 for each in-node and 10 for each out-node.
#  * The `bias` and `dropout` are internal parameters of the model.

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now let's create the actual Keras model with the graph inputs `x_inp` provided by the `graph_model` and outputs being the predictions from the softmax layer

# %% [markdown]
# Now we create a model to predict the 7 categories using Keras softmax layers.

# %%
import tensorflow as tf
from tensorflow import keras
from stellargraph.layer import MaxPoolingAggregator

METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
]

def make_model(metrics = METRICS, output_bias=None):
    if output_bias is not None:
        output_bias = tf.keras.initializers.Constant(output_bias)

    graphsage_model = DirectedGraphSAGE(
        # original [32, 32]
        layer_sizes=[32, 32], generator=generator, bias=True, dropout=0.5,
    )    
    
    x_inp, x_out = graphsage_model.in_out_tensors()
    prediction = layers.Dense(units=train_targets.shape[1], activation="sigmoid", bias_initializer=output_bias)(x_out)

    model = Model(inputs=x_inp, outputs=prediction)
    model.compile(
        optimizer=optimizers.Adam(lr=1e-3),
        loss=losses.BinaryCrossentropy(),
        metrics=metrics,
    )

    return model

# %%
EPOCHS = 100

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

initial_bias = np.log([pos/neg])
initial_bias

model = make_model(output_bias = initial_bias)
# model.predict(train_features[:10])

initial_weights = os.path.join(tempfile.mkdtemp(), 'initial_weights')
model.save_weights(initial_weights)
# weighted_model.load_weights(initial_weights)

val_gen = generator.flow(val_subjects.index, val_targets)
test_gen = generator.flow(test_subjects.index, test_targets)

# %%
history = model.fit(
    train_gen,
    epochs=EPOCHS,
    callbacks = [early_stopping],
    shuffle=False, 
    validation_data=val_gen)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 564 steps, validate for 176 steps
# Epoch 1/100
# 564/564 [==============================] - 20s 35ms/step - loss: 0.4057 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5456 - val_loss: 0.3981 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5866
# Epoch 2/100
# 564/564 [==============================] - 16s 29ms/step - loss: 0.4033 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5730 - val_loss: 0.3941 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6195
# Epoch 3/100
# 564/564 [==============================] - 17s 30ms/step - loss: 0.4007 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5906 - val_loss: 0.3906 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6417
# Epoch 4/100
# 564/564 [==============================] - 23s 40ms/step - loss: 0.3995 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5990 - val_loss: 0.3872 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.64870 - fn: 2370.0000 - accuracy: 0.8593 - precision: 0.0000e+00 - recall: 0.0000e+ - ETA: 7s - loss: 0.3973 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 15176.0000 - fn: 2474.0000 - accuracy: 0.8598 - precision: 0 - ETA: 5s - loss: 0.3981 - tp: 0.0000e+00 - fp: 0.0000e+0 - ETA: 1s - loss: 0.3975 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 22013.0000 - fn: 3587.0000 - accuracy: 0.8599 - prec
# Epoch 5/100
# 564/564 [==============================] - 21s 37ms/step - loss: 0.3953 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6229 - val_loss: 0.3828 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6639
# Epoch 6/100
# 564/564 [==============================] - 19s 34ms/step - loss: 0.3963 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6131 - val_loss: 0.3820 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6631
# Epoch 7/100
# 564/564 [==============================] - 19s 34ms/step - loss: 0.3951 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6175 - val_loss: 0.3807 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6679
# Epoch 8/100
# 564/564 [==============================] - 19s 34ms/step - loss: 0.3912 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6363 - val_loss: 0.3787 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6687fp: 0.0000e+00 - tn: 12081.0000 - fn: 1969.0000 - a - ETA: 5s - loss: 0.3884 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 15617.0000 - fn: 2533.0000 - accuracy: 0.8604 - precision: 0.0000e+00 - recall - ETA: 4s - loss: 0.3902 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 16842.0000 - fn: 2758.0000 - accuracy: 0.8593 - precision: 0.0000e+00 - recall: 0.0000e+00 - - ETA: 4s - loss: 0.3898 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 17406.0000 - fn: 2844.0000 - accuracy: 0.8596 - precision: 0.0 - ETA: 3s - loss: 0.3897 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 19388.
# Epoch 9/100
# 564/564 [==============================] - 19s 34ms/step - loss: 0.3899 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6382 - val_loss: 0.3787 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1219.0000 - val_accuracy: 0.8615 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6643
# Epoch 10/100
# 564/564 [==============================] - 21s 37ms/step - loss: 0.3906 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3974.0000 - accuracy: 0.8589 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6355 - val_loss: 0.3789 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1217.0000 - val_accuracy: 0.8617 - val_precision: 1.0000 - val_recall: 0.0016 - val_auc: 0.6591fp: 0.0000e+00 - tn: 13140.0000 - fn: 2160.0000 - accuracy: 0.8588 - precision: 0.0000e+00 -  - ETA: 6s - loss: 0.3887 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 14522.0000 - fn: 2378.0000 - a - ETA: 4s - loss: 0.3891 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 17790.0000 - fn: 2910.0000 - accuracy: 0.8594 - precision: 0.0000e+00 - recall:  - ETA: 3s - loss: 0.3896 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 19036.0000 - fn: 3114.0000 - accuracy: 0.8594 - precision: 0 - ETA: 2s - loss: 0.3908 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 21045.0000 - fn: 3455.0000 - accurac
# Epoch 11/100
# 564/564 [==============================] - 21s 37ms/step - loss: 0.3888 - tp: 6.0000 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3968.0000 - accuracy: 0.8591 - precision: 1.0000 - recall: 0.0015 - auc: 0.6403 - val_loss: 0.3793 - val_tp: 6.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1213.0000 - val_accuracy: 0.8622 - val_precision: 1.0000 - val_recall: 0.0049 - val_auc: 0.6558- fp: 0.0000e+00 - tn: 14173.0000 - fn: 2326.0000 - accuracy: 0.8590 - precision: 1.0000 -  - ETA: 0s - loss: 0.3873 - tp: 5.0000 - fp: 0.0000e+00 - tn: 23040.0000 - fn: 3755.0000 - accuracy: 0.8599 - precision: 1.0000 - re
# Epoch 12/100
# 564/564 [==============================] - 30s 53ms/step - loss: 0.3881 - tp: 19.0000 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3955.0000 - accuracy: 0.8596 - precision: 1.0000 - recall: 0.0048 - auc: 0.6410 - val_loss: 0.3779 - val_tp: 16.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1203.0000 - val_accuracy: 0.8633 - val_precision: 1.0000 - val_recall: 0.0131 - val_auc: 0.6580
# Epoch 13/100
# 564/564 [==============================] - 23s 41ms/step - loss: 0.3880 - tp: 46.0000 - fp: 0.0000e+00 - tn: 24186.0000 - fn: 3928.0000 - accuracy: 0.8605 - precision: 1.0000 - recall: 0.0116 - auc: 0.6404 - val_loss: 0.3774 - val_tp: 10.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1209.0000 - val_accuracy: 0.8626 - val_precision: 1.0000 - val_recall: 0.0082 - val_auc: 0.6608
# Epoch 14/100
# 564/564 [==============================] - 20s 36ms/step - loss: 0.3868 - tp: 41.0000 - fp: 2.0000 - tn: 24184.0000 - fn: 3933.0000 - accuracy: 0.8603 - precision: 0.9535 - recall: 0.0103 - auc: 0.6428 - val_loss: 0.3781 - val_tp: 19.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1200.0000 - val_accuracy: 0.8636 - val_precision: 1.0000 - val_recall: 0.0156 - val_auc: 0.6576: 3422.0000 - accuracy: 0.8600 - precision: 0.9375 - recall: - ETA: 0s - loss: 0.3850 - tp: 35.0000 - fp: 2.0000 - tn: 22913.0000 - fn: 3700.0000 - accuracy: 0.8611 - precision: 0.9459 - recall: 0.009
# Epoch 15/100
# 564/564 [==============================] - 22s 39ms/step - loss: 0.3880 - tp: 56.0000 - fp: 4.0000 - tn: 24182.0000 - fn: 3918.0000 - accuracy: 0.8607 - precision: 0.9333 - recall: 0.0141 - auc: 0.6379 - val_loss: 0.3781 - val_tp: 13.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1206.0000 - val_accuracy: 0.8630 - val_precision: 1.0000 - val_recall: 0.0107 - val_auc: 0.6551uracy: 0.8611 - precision: 0.9500 - recall: 0.0102 - auc: 0. - ETA: 10s -
# Epoch 16/100
# 564/564 [==============================] - 22s 38ms/step - loss: 0.3859 - tp: 82.0000 - fp: 6.0000 - tn: 24180.0000 - fn: 3892.0000 - accuracy: 0.8616 - precision: 0.9318 - recall: 0.0206 - auc: 0.6452 - val_loss: 0.3756 - val_tp: 30.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1189.0000 - val_accuracy: 0.8649 - val_precision: 1.0000 - val_recall: 0.0246 - val_auc: 0.6639621 - precision: 0.9524 - recal - ETA: 1s - loss: 0.3839 - tp: 74.0000 - fp: 5.0000 - tn: 22094.0000 - fn: 3527.0000 - accuracy: 0.8626 - precision: 0.9367 - r
# Epoch 17/100
# 564/564 [==============================] - 20s 36ms/step - loss: 0.3844 - tp: 98.0000 - fp: 8.0000 - tn: 24178.0000 - fn: 3876.0000 - accuracy: 0.8621 - precision: 0.9245 - recall: 0.0247 - auc: 0.6521 - val_loss: 0.3732 - val_tp: 36.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1183.0000 - val_accuracy: 0.8656 - val_precision: 1.0000 - val_recall: 0.0295 - val_auc: 0.6715
# Epoch 18/100
# 564/564 [==============================] - 22s 38ms/step - loss: 0.3850 - tp: 112.0000 - fp: 11.0000 - tn: 24175.0000 - fn: 3862.0000 - accuracy: 0.8625 - precision: 0.9106 - recall: 0.0282 - auc: 0.6443 - val_loss: 0.3756 - val_tp: 25.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1194.0000 - val_accuracy: 0.8643 - val_precision: 1.0000 - val_recall: 0.0205 - val_auc: 0.6635
# Epoch 19/100
# 564/564 [==============================] - 21s 37ms/step - loss: 0.3861 - tp: 110.0000 - fp: 12.0000 - tn: 24174.0000 - fn: 3864.0000 - accuracy: 0.8624 - precision: 0.9016 - recall: 0.0277 - auc: 0.6434 - val_loss: 0.3769 - val_tp: 31.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1188.0000 - val_accuracy: 0.8650 - val_precision: 1.0000 - val_recall: 0.0254 - val_auc: 0.6579
# Epoch 20/100
# 564/564 [==============================] - 22s 38ms/step - loss: 0.3841 - tp: 134.0000 - fp: 19.0000 - tn: 24167.0000 - fn: 3840.0000 - accuracy: 0.8630 - precision: 0.8758 - recall: 0.0337 - auc: 0.6487 - val_loss: 0.3750 - val_tp: 38.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1181.0000 - val_accuracy: 0.8658 - val_precision: 1.0000 - val_recall: 0.0312 - val_auc: 0.6615
# Epoch 21/100
# 564/564 [==============================] - 22s 39ms/step - loss: 0.3832 - tp: 155.0000 - fp: 35.0000 - tn: 24151.0000 - fn: 3819.0000 - accuracy: 0.8631 - precision: 0.8158 - recall: 0.0390 - auc: 0.6495 - val_loss: 0.3762 - val_tp: 37.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1182.0000 - val_accuracy: 0.8657 - val_precision: 1.0000 - val_recall: 0.0304 - val_auc: 0.6586
# Epoch 22/100
# 564/564 [==============================] - 24s 43ms/step - loss: 0.3851 - tp: 140.0000 - fp: 21.0000 - tn: 24165.0000 - fn: 3834.0000 - accuracy: 0.8631 - precision: 0.8696 - recall: 0.0352 - auc: 0.6436 - val_loss: 0.3736 - val_tp: 45.0000 - val_fp: 1.0000 - val_tn: 7580.0000 - val_fn: 1174.0000 - val_accuracy: 0.8665 - val_precision: 0.9783 - val_recall: 0.0369 - val_auc: 0.6634
# Epoch 23/100
# 564/564 [==============================] - 30s 53ms/step - loss: 0.3845 - tp: 159.0000 - fp: 24.0000 - tn: 24162.0000 - fn: 3815.0000 - accuracy: 0.8637 - precision: 0.8689 - recall: 0.0400 - auc: 0.6445 - val_loss: 0.3742 - val_tp: 53.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1166.0000 - val_accuracy: 0.8675 - val_precision: 1.0000 - val_recall: 0.0435 - val_auc: 0.6604
# Epoch 24/100
# 564/564 [==============================] - 22s 38ms/step - loss: 0.3840 - tp: 175.0000 - fp: 39.0000 - tn: 24147.0000 - fn: 3799.0000 - accuracy: 0.8637 - precision: 0.8178 - recall: 0.0440 - auc: 0.6455 - val_loss: 0.3732 - val_tp: 51.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1168.0000 - val_accuracy: 0.8673 - val_precision: 1.0000 - val_recall: 0.0418 - val_auc: 0.6670
# Epoch 25/100
# 564/564 [==============================] - 20s 36ms/step - loss: 0.3831 - tp: 167.0000 - fp: 46.0000 - tn: 24140.0000 - fn: 3807.0000 - accuracy: 0.8632 - precision: 0.7840 - recall: 0.0420 - auc: 0.6515 - val_loss: 0.3734 - val_tp: 59.0000 - val_fp: 1.0000 - val_tn: 7580.0000 - val_fn: 1160.0000 - val_accuracy: 0.8681 - val_precision: 0.9833 - val_recall: 0.0484 - val_auc: 0.6599
# Epoch 26/100
# 564/564 [==============================] - 23s 41ms/step - loss: 0.3828 - tp: 194.0000 - fp: 50.0000 - tn: 24136.0000 - fn: 3780.0000 - accuracy: 0.8640 - precision: 0.7951 - recall: 0.0488 - auc: 0.6510 - val_loss: 0.3754 - val_tp: 34.0000 - val_fp: 0.0000e+00 - val_tn: 7581.0000 - val_fn: 1185.0000 - val_accuracy: 0.8653 - val_precision: 1.0000 - val_recall: 0.0279 - val_auc: 0.6628
# Epoch 27/100
# 562/564 [============================>.] - ETA: 0s - loss: 0.3824 - tp: 197.0000 - fp: 39.0000 - tn: 24096.0000 - fn: 3768.0000 - accuracy: 0.8645 - precision: 0.8347 - recall: 0.0497 - auc: 0.6510- ETA: 5s - loss: 0.3808 - tp: 132.0000 - fp: 27.0000 - tn: 16943.0000 - fn: Restoring model weights from the end of the best epoch.
# 564/564 [==============================] - 23s 41ms/step - loss: 0.3824 - tp: 197.0000 - fp: 39.0000 - tn: 24147.0000 - fn: 3777.0000 - accuracy: 0.8645 - precision: 0.8347 - recall: 0.0496 - auc: 0.6513 - val_loss: 0.3713 - val_tp: 61.0000 - val_fp: 1.0000 - val_tn: 7580.0000 - val_fn: 1158.0000 - val_accuracy: 0.8683 - val_precision: 0.9839 - val_recall: 0.0500 - val_auc: 0.6666
# Epoch 00027: early stopping

# %% [markdown]
# Train the model, keeping track of its loss and accuracy on the training set, and its generalisation performance on the test set (we need to create another generator over the test data for this)

# %%
def plot_metrics(history):
  metrics =  ['loss', 'auc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

# %%
plot_metrics(history)

# %% [markdown]
# Now we have trained the model we can evaluate on the test set.

# %% [markdown]
# ### Evaluate metrics
#
# You can use a [confusion matrix](https://developers.google.com/machine-learning/glossary/#confusion_matrix) to summarize the actual vs. predicted labels where the X axis is the predicted label and the Y axis is the actual label.

# %%
train_predictions_baseline = model.predict(train_gen)
test_predictions_baseline = model.predict(test_gen)

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))

# %% [markdown]
# Evaluate your model on the test dataset and display the results for the metrics you created above.

# %%
test_metrics = model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 141/141 [==============================] - 3s 21ms/step - loss: 0.3824 - tp: 26.0000 - fp: 0.0000e+00 - tn: 6019.0000 - fn: 995.0000 - accuracy: 0.8587 - precision: 1.0000 - recall: 0.0255 - auc: 0.6795
#
# Test Set Metrics:
# 	loss: 0.3824
# 	tp: 26.0000
# 	fp: 0.0000
# 	tn: 6019.0000
# 	fn: 995.0000
# 	accuracy: 0.8587
# 	precision: 1.0000
# 	recall: 0.0255
# 	auc: 0.6795

# %%
print(confusion_matrix(test_subjects, test_predictions_baseline > 0.5))
print(classification_report(test_subjects, test_predictions_baseline > 0.5))
# Out:
# [[6019    0]
#  [ 994   27]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-8a988e2a8e32> in <module>
#       1 print(confusion_matrix(test_subjects, test_predictions_baseline > 0.5))
# ----> 2 print(classification_report(test_subjects, test_predictions_baseline > 0.5))
#
# NameError: name 'classification_report' is not defined

# %%
plot_cm(test_subjects, test_predictions_baseline)
# Out:
# Legitimate Transactions Detected (True Negatives):  6019
# Legitimate Transactions Incorrectly Detected (False Positives):  0
# Fraudulent Transactions Missed (False Negatives):  994
# Fraudulent Transactions Detected (True Positives):  27
# Total Fraudulent Transactions:  1021

# %% [markdown]
# If the model had predicted everything perfectly, this would be a [diagonal matrix](https://en.wikipedia.org/wiki/Diagonal_matrix) where values off the main diagonal, indicating incorrect predictions, would be zero. In this case the matrix shows that you have relatively few false positives, meaning that there were relatively few legitimate transactions that were incorrectly flagged. However, you would likely want to have even fewer false negatives despite the cost of increasing the number of false positives. This trade off may be preferable because false negatives would allow fraudulent transactions to go through, whereas false positives may cause an email to be sent to a customer to ask them to verify their card activity.

# %% [markdown]
# ### Plot the ROC
#
# Now plot the [ROC](https://developers.google.com/machine-learning/glossary#ROC). This plot is useful because it shows, at a glance, the range of performance the model can reach just by tuning the output threshold.

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)

  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.xlim([-0.5,100.5])
  plt.ylim([-0.5,100.5])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
plot_roc("Train Baseline", train_subjects, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", test_subjects, test_predictions_baseline, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# ### Save this model

# %%
# Save model
filename = 'models/keras_graphsage/no_weight_model_highprecision_lowrecall'
model.save(filename)
# Out:
# WARNING:tensorflow:From C:\Users\ttr\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: models/keras_graphsage/no_weight_model_highprecision_lowrecall\assets

# %%
keras_graphsage_model = keras.models.load_model('models/keras_graphsage/no_weight_model_highprecision_lowrecall')

# %%
evaluation_predictions_baseline = keras_graphsage_model.predict(test_gen)
plot_cm(test_subjects, evaluation_predictions_baseline)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-60-cbd25b0d5395> in <module>
# ----> 1 evaluation_predictions_baseline = keras_graphsage_model.predict(test_gen)
#       2 plot_cm(test_subjects, evaluation_predictions_baseline)
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1011         max_queue_size=max_queue_size,
#    1012         workers=workers,
# -> 1013         use_multiprocessing=use_multiprocessing)
#    1014
#    1015   def reset_metrics(self):
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in predict(self, model, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     496         model, ModeKeys.PREDICT, x=x, batch_size=batch_size, verbose=verbose,
#     497         steps=steps, callbacks=callbacks, max_queue_size=max_queue_size,
# --> 498         workers=workers, use_multiprocessing=use_multiprocessing, **kwargs)
#     499
#     500
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     473               mode=mode,
#     474               training_context=training_context,
# --> 475               total_epochs=1)
#     476           cbks.make_logs(model, epoch_logs, result, mode)
#     477
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     636               *args, **kwds)
#     637       # If we did not create any variables the trace we have is good enough.
# --> 638       return self._concrete_stateful_fn._filtered_call(canon_args, canon_kwds)  # pylint: disable=protected-access
#     639
#     640     def fn_with_cond(*inner_args, **inner_kwds):
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\Anaconda3\envs\july\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# ~\Anaconda3\envs\july\lib\site-packages\six.py in raise_from(value, from_value)
#
# InvalidArgumentError:  Input to reshape is a tensor with 37500 values, but the requested shape has 150000
# 	 [[{{node model_9/reshape_82/PartitionedCall/PartitionedCall/Reshape}}]] [Op:__inference_distributed_function_288436]
#
# Function call stack:
# distributed_function

# %% [markdown]
# It looks like the precision is relatively high, but the recall and the area under the ROC curve (AUC) aren't as high as you might like. Classifiers often face challenges when trying to maximize both precision and recall, which is especially true when working with imbalanced datasets. It is important to consider the costs of different types of errors in the context of the problem you care about. In this example, a false negative (a fraudulent transaction is missed) may have a financial cost, while a false positive (a transaction is incorrectly flagged as fraudulent) may decrease user happiness.

# %% [markdown]
# ### Class weights

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.58
# Weight for class 1: 3.54

# %%
weighted_model = make_model()
weighted_model.load_weights(initial_weights)

weighted_history = weighted_model.fit(
    train_gen,
    epochs=EPOCHS,
    callbacks = [early_stopping],
    validation_data=val_gen,
    # The class weights go here
    class_weight=class_weight)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 282 steps, validate for 88 steps
# Epoch 1/100
# 282/282 [==============================] - 134s 473ms/step - loss: 0.6923 - tp: 1754.0000 - fp: 9028.0000 - tn: 15180.0000 - fn: 2198.0000 - accuracy: 0.6013 - precision: 0.1627 - recall: 0.4438 - auc: 0.5451 - val_loss: 0.6756 - val_tp: 606.0000 - val_fp: 2715.0000 - val_tn: 4847.0000 - val_fn: 632.0000 - val_accuracy: 0.6197 - val_precision: 0.1825 - val_recall: 0.4895 - val_auc: 0.6225
# Epoch 2/100
# 282/282 [==============================] - 137s 484ms/step - loss: 0.6737 - tp: 2322.0000 - fp: 10419.0000 - tn: 13789.0000 - fn: 1630.0000 - accuracy: 0.5721 - precision: 0.1822 - recall: 0.5876 - auc: 0.6135 - val_loss: 0.6747 - val_tp: 545.0000 - val_fp: 2080.0000 - val_tn: 5482.0000 - val_fn: 693.0000 - val_accuracy: 0.6849 - val_precision: 0.2076 - val_recall: 0.4402 - val_auc: 0.6397
# Epoch 3/100
# 282/282 [==============================] - 136s 483ms/step - loss: 0.6632 - tp: 2369.0000 - fp: 9963.0000 - tn: 14245.0000 - fn: 1583.0000 - accuracy: 0.5900 - precision: 0.1921 - recall: 0.5994 - auc: 0.6351 - val_loss: 0.6668 - val_tp: 603.0000 - val_fp: 2380.0000 - val_tn: 5182.0000 - val_fn: 635.0000 - val_accuracy: 0.6574 - val_precision: 0.2021 - val_recall: 0.4871 - val_auc: 0.6475
# Epoch 4/100
# 282/282 [==============================] - 137s 485ms/step - loss: 0.6545 - tp: 2397.0000 - fp: 9620.0000 - tn: 14588.0000 - fn: 1555.0000 - accuracy: 0.6032 - precision: 0.1995 - recall: 0.6065 - auc: 0.6518 - val_loss: 0.6479 - val_tp: 640.0000 - val_fp: 2215.0000 - val_tn: 5347.0000 - val_fn: 598.0000 - val_accuracy: 0.6803 - val_precision: 0.2242 - val_recall: 0.5170 - val_auc: 0.6689
# Epoch 5/100
# 282/282 [==============================] - 138s 489ms/step - loss: 0.6461 - tp: 2381.0000 - fp: 9137.0000 - tn: 15071.0000 - fn: 1571.0000 - accuracy: 0.6197 - precision: 0.2067 - recall: 0.6025 - auc: 0.6646 - val_loss: 0.6636 - val_tp: 578.0000 - val_fp: 1851.0000 - val_tn: 5711.0000 - val_fn: 660.0000 - val_accuracy: 0.7147 - val_precision: 0.2380 - val_recall: 0.4669 - val_auc: 0.6605
# Epoch 6/100
# 282/282 [==============================] - 136s 483ms/step - loss: 0.6394 - tp: 2408.0000 - fp: 8882.0000 - tn: 15326.0000 - fn: 1544.0000 - accuracy: 0.6298 - precision: 0.2133 - recall: 0.6093 - auc: 0.6753 - val_loss: 0.6720 - val_tp: 531.0000 - val_fp: 1634.0000 - val_tn: 5928.0000 - val_fn: 707.0000 - val_accuracy: 0.7340 - val_precision: 0.2453 - val_recall: 0.4289 - val_auc: 0.6657
# Epoch 7/100
# 282/282 [==============================] - 143s 506ms/step - loss: 0.6373 - tp: 2392.0000 - fp: 8711.0000 - tn: 15497.0000 - fn: 1560.0000 - accuracy: 0.6353 - precision: 0.2154 - recall: 0.6053 - auc: 0.6762 - val_loss: 0.7134 - val_tp: 355.0000 - val_fp: 871.0000 - val_tn: 6691.0000 - val_fn: 883.0000 - val_accuracy: 0.8007 - val_precision: 0.2896 - val_recall: 0.2868 - val_auc: 0.6620
# Epoch 8/100
# 282/282 [==============================] - 153s 542ms/step - loss: 0.6300 - tp: 2371.0000 - fp: 8209.0000 - tn: 15999.0000 - fn: 1581.0000 - accuracy: 0.6523 - precision: 0.2241 - recall: 0.5999 - auc: 0.6864 - val_loss: 0.6442 - val_tp: 564.0000 - val_fp: 1591.0000 - val_tn: 5971.0000 - val_fn: 674.0000 - val_accuracy: 0.7426 - val_precision: 0.2617 - val_recall: 0.4556 - val_auc: 0.6854
# Epoch 9/100
# 282/282 [==============================] - 154s 547ms/step - loss: 0.6294 - tp: 2360.0000 - fp: 8216.0000 - tn: 15992.0000 - fn: 1592.0000 - accuracy: 0.6517 - precision: 0.2231 - recall: 0.5972 - auc: 0.6866 - val_loss: 0.7006 - val_tp: 432.0000 - val_fp: 1111.0000 - val_tn: 6451.0000 - val_fn: 806.0000 - val_accuracy: 0.7822 - val_precision: 0.2800 - val_recall: 0.3489 - val_auc: 0.6645
# Epoch 10/100
# 282/282 [==============================] - 159s 564ms/step - loss: 0.6277 - tp: 2366.0000 - fp: 8186.0000 - tn: 16022.0000 - fn: 1586.0000 - accuracy: 0.6530 - precision: 0.2242 - recall: 0.5987 - auc: 0.6882 - val_loss: 0.6763 - val_tp: 479.0000 - val_fp: 1261.0000 - val_tn: 6301.0000 - val_fn: 759.0000 - val_accuracy: 0.7705 - val_precision: 0.2753 - val_recall: 0.3869 - val_auc: 0.6709
# Epoch 11/100
# 282/282 [==============================] - 155s 548ms/step - loss: 0.6225 - tp: 2373.0000 - fp: 7852.0000 - tn: 16356.0000 - fn: 1579.0000 - accuracy: 0.6651 - precision: 0.2321 - recall: 0.6005 - auc: 0.6960 - val_loss: 0.7107 - val_tp: 303.0000 - val_fp: 656.0000 - val_tn: 6906.0000 - val_fn: 935.0000 - val_accuracy: 0.8192 - val_precision: 0.3160 - val_recall: 0.2447 - val_auc: 0.6691
# Epoch 12/100
# 282/282 [==============================] - 155s 549ms/step - loss: 0.6246 - tp: 2347.0000 - fp: 7908.0000 - tn: 16300.0000 - fn: 1605.0000 - accuracy: 0.6622 - precision: 0.2289 - recall: 0.5939 - auc: 0.6921 - val_loss: 0.7141 - val_tp: 225.0000 - val_fp: 258.0000 - val_tn: 7304.0000 - val_fn: 1013.0000 - val_accuracy: 0.8556 - val_precision: 0.4658 - val_recall: 0.1817 - val_auc: 0.6844
# Epoch 13/100
# 282/282 [==============================] - 150s 531ms/step - loss: 0.6234 - tp: 2340.0000 - fp: 7768.0000 - tn: 16440.0000 - fn: 1612.0000 - accuracy: 0.6669 - precision: 0.2315 - recall: 0.5921 - auc: 0.6919 - val_loss: 0.7452 - val_tp: 200.0000 - val_fp: 196.0000 - val_tn: 7366.0000 - val_fn: 1038.0000 - val_accuracy: 0.8598 - val_precision: 0.5051 - val_recall: 0.1616 - val_auc: 0.6735
# Epoch 14/100
# 282/282 [==============================] - 141s 501ms/step - loss: 0.6254 - tp: 2289.0000 - fp: 7729.0000 - tn: 16479.0000 - fn: 1663.0000 - accuracy: 0.6665 - precision: 0.2285 - recall: 0.5792 - auc: 0.6892 - val_loss: 0.8016 - val_tp: 211.0000 - val_fp: 387.0000 - val_tn: 7175.0000 - val_fn: 1027.0000 - val_accuracy: 0.8393 - val_precision: 0.3528 - val_recall: 0.1704 - val_auc: 0.6476
# Epoch 15/100
# 282/282 [==============================] - 138s 489ms/step - loss: 0.6202 - tp: 2344.0000 - fp: 7762.0000 - tn: 16446.0000 - fn: 1608.0000 - accuracy: 0.6673 - precision: 0.2319 - recall: 0.5931 - auc: 0.6977 - val_loss: 0.6914 - val_tp: 381.0000 - val_fp: 856.0000 - val_tn: 6706.0000 - val_fn: 857.0000 - val_accuracy: 0.8053 - val_precision: 0.3080 - val_recall: 0.3078 - val_auc: 0.6773
# Epoch 16/100
# 282/282 [==============================] - 146s 518ms/step - loss: 0.6192 - tp: 2349.0000 - fp: 7621.0000 - tn: 16587.0000 - fn: 1603.0000 - accuracy: 0.6724 - precision: 0.2356 - recall: 0.5944 - auc: 0.7001 - val_loss: 0.7582 - val_tp: 248.0000 - val_fp: 525.0000 - val_tn: 7037.0000 - val_fn: 990.0000 - val_accuracy: 0.8278 - val_precision: 0.3208 - val_recall: 0.2003 - val_auc: 0.6598
# Epoch 17/100
# 282/282 [==============================] - 147s 520ms/step - loss: 0.6122 - tp: 2393.0000 - fp: 7422.0000 - tn: 16786.0000 - fn: 1559.0000 - accuracy: 0.6811 - precision: 0.2438 - recall: 0.6055 - auc: 0.7093 - val_loss: 0.7949 - val_tp: 234.0000 - val_fp: 527.0000 - val_tn: 7035.0000 - val_fn: 1004.0000 - val_accuracy: 0.8260 - val_precision: 0.3075 - val_recall: 0.1890 - val_auc: 0.6552
# Epoch 18/100
# 281/282 [============================>.] - ETA: 0s - loss: 0.6158 - tp: 2306.0000 - fp: 7481.0000 - tn: 16641.0000 - fn: 1632.0000 - accuracy: 0.6752 - precision: 0.2356 - recall: 0.5856 - auc: 0.7019Restoring model weights from the end of the best epoch.
# 282/282 [==============================] - 141s 501ms/step - loss: 0.6157 - tp: 2314.0000 - fp: 7501.0000 - tn: 16707.0000 - fn: 1638.0000 - accuracy: 0.6755 - precision: 0.2358 - recall: 0.5855 - auc: 0.7022 - val_loss: 0.7664 - val_tp: 224.0000 - val_fp: 478.0000 - val_tn: 7084.0000 - val_fn: 1014.0000 - val_accuracy: 0.8305 - val_precision: 0.3191 - val_recall: 0.1809 - val_auc: 0.6574
# Epoch 00018: early stopping

# %% [markdown]
# ### Check training history

# %%
plot_metrics(weighted_history)

# %% [markdown]
# ### Evaluate metrics

# %%
train_predictions_weighted = weighted_model.predict(train_gen)
test_predictions_weighted = weighted_model.predict(test_gen)

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))

# %% [markdown]
# Evaluate your model on the test dataset and display the results for the metrics you created above.

# %%
test_metrics = weighted_model.evaluate(test_gen)
print("\nTest Set Metrics:")
for name, val in zip(weighted_model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 71/71 [==============================] - 17s 234ms/step - loss: 0.5376 - tp: 438.0000 - fp: 1294.0000 - tn: 4722.0000 - fn: 586.0000 - accuracy: 0.7330 - precision: 0.2529 - recall: 0.4277 - auc: 0.6743s - loss: 0.5381 - tp: 95.0000 - fp: 318.0000 - tn: 1158.0000 - fn: 129.000 - ETA: 1s - loss: 0.5370 - tp: 396.0000 - fp: 1168.0000 - tn: 4297.0000 - fn: 539.0000 - accuracy: 0.7333 - precision: 0.2532 - recall: 0.4235 - auc:
#
# Test Set Metrics:
# 	loss: 0.5376
# 	tp: 438.0000
# 	fp: 1294.0000
# 	tn: 4722.0000
# 	fn: 586.0000
# 	accuracy: 0.7330
# 	precision: 0.2529
# 	recall: 0.4277
# 	auc: 0.6743

# %%
plot_cm(test_subjects, test_predictions_weighted)
# Out:
# Legitimate Transactions Detected (True Negatives):  4711
# Legitimate Transactions Incorrectly Detected (False Positives):  1305
# Fraudulent Transactions Missed (False Negatives):  582
# Fraudulent Transactions Detected (True Positives):  442
# Total Fraudulent Transactions:  1024

# %% [markdown]
# If the model had predicted everything perfectly, this would be a [diagonal matrix](https://en.wikipedia.org/wiki/Diagonal_matrix) where values off the main diagonal, indicating incorrect predictions, would be zero. In this case the matrix shows that you have relatively few false positives, meaning that there were relatively few legitimate transactions that were incorrectly flagged. However, you would likely want to have even fewer false negatives despite the cost of increasing the number of false positives. This trade off may be preferable because false negatives would allow fraudulent transactions to go through, whereas false positives may cause an email to be sent to a customer to ask them to verify their card activity.

# %% [markdown]
# ### Plot the ROC
#
# Now plot the [ROC](https://developers.google.com/machine-learning/glossary#ROC). This plot is useful because it shows, at a glance, the range of performance the model can reach just by tuning the output threshold.

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)

  plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.xlim([-0.5,100.5])
  plt.ylim([-0.5,100.5])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
plot_roc("Train Baseline", train_subjects, train_predictions_weighted, color=colors[0])
plot_roc("Test Baseline", test_subjects, test_predictions_weighted, color=colors[0], linestyle='--')
plt.legend(loc='lower right')

# %% [markdown]
# It looks like the precision is relatively high, but the recall and the area under the ROC curve (AUC) aren't as high as you might like. Classifiers often face challenges when trying to maximize both precision and recall, which is especially true when working with imbalanced datasets. It is important to consider the costs of different types of errors in the context of the problem you care about. In this example, a false negative (a fraudulent transaction is missed) may have a financial cost, while a false positive (a transaction is incorrectly flagged as fraudulent) may decrease user happiness.

# %% [markdown]
# ### Save this model

# %%
# Save model
filename = 'models/keras_graphsage/weighted_model_lowprecision_highrecall'
weighted_model.save(filename)
# Out:
# INFO:tensorflow:Assets written to: models/keras_graphsage/weighted_model_lowprecision_highrecall\assets

# %%
keras_graphsage_weighted_model = keras.models.load_model('models/keras_graphsage/weighted_model_lowprecision_highrecall')

# %%
evaluation_predictions_baseline = keras_graphsage_weighted_model.predict(test_gen)
plot_cm(test_subjects, evaluation_predictions_baseline)
# Out:
# Legitimate Transactions Detected (True Negatives):  4717
# Legitimate Transactions Incorrectly Detected (False Positives):  1299
# Fraudulent Transactions Missed (False Negatives):  587
# Fraudulent Transactions Detected (True Positives):  437
# Total Fraudulent Transactions:  1024

# %% [markdown]
# <table><tr><td>Run the latest release of this notebook:</td><td><a href="https://mybinder.org/v2/gh/stellargraph/stellargraph/master?urlpath=lab/tree/demos/node-classification/directed-graphsage-node-classification.ipynb" alt="Open In Binder" target="_parent"><img src="https://mybinder.org/badge_logo.svg"/></a></td><td><a href="https://colab.research.google.com/github/stellargraph/stellargraph/blob/master/demos/node-classification/directed-graphsage-node-classification.ipynb" alt="Open In Colab" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg"/></a></td></tr></table>
